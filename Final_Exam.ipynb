# %% [markdown]
# <a href="https://colab.research.google.com/github/chuangchai49097/data_viz_2022/blob/main/Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # เตรียมข้อมูล

# %%
import pandas as pd # import ฟังก์ชัน pandas

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่าMounted at /content/drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os # จัดการเกี่ยวกับไฟล์ต่างๆ ในโฟล์เดอร์

# %%
path = '/content/drive/My Drive/dataviz_2021_data' # ชี้ว่า data เราอยู่โฟล์เดอร์ไหน

# %%
data_file_path = os.path.join(path,'alldb.csv') # เอาที่อยู่ของไฟล์เชื่อมกับที่อยู่ของไฟล์เรา โดยกำหนดชื่่อไฟล์ที่เราต้องการ
data_alldb = pd.read_csv(data_file_path)

# %%
data_alldb
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# 0      NaN         NaN  NaN               NaN    NaN       NaN
# 1      NaN  2022-02-24  NaN        iPhone10,4  05310  10:50:32
# 2      NaN         NaN  NaN               NaN    NaN       NaN
# 3      NaN  2022-02-23    0        iPhone13,4  05087  09:59:47
# 4      NaN  2022-02-23  NaN        iPhone13,4  05087  09:44:06
# ...    ...         ...  ...               ...    ...       ...
# 40030  NaN         NaN  NaN        iPhone13,4  01234       NaN
# 40031  NaN         NaN    2        iPhone10,5  01234       NaN
# 40032  NaN         NaN    1        iPhone13,4  01234       NaN
# 40033  NaN         NaN  NaN  Samsung SM-A115F  01234       NaN
# 40034  NaN         NaN    1  Samsung SM-A115F  01234       NaN
#
#                  urine  pid            PartitionKey                  title  \
# 0                  NaN  NaN                     NaN  data is not completed
# 1                  NaN  NaN                     NaN  data is not completed
# 2                  NaN  NaN                     NaN  data is not completed
# 3      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# 4      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# ...                ...  ...                     ...                    ...
# 40030              NaN    5     เกษศิรินทร์  ไชยลาภ  data is not completed
# 40031  ปกติ (เหลืองใส)    5  เถลิงเกียรติ เสริฐเลิศ  data is not completed
# 40032  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
# 40033              NaN    1                    เสรี  data is not completed
# 40034  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
#
#                          age
# 0      data is not completed
# 1      data is not completed
# 2      data is not completed
# 3      data is not completed
# 4      data is not completed
# ...                      ...
# 40030  data is not completed
# 40031  data is not completed
# 40032  data is not completed
# 40033  data is not completed
# 40034  data is not completed
#
# [40035 rows x 14 columns]

# %%
data_file_path2 = os.path.join(path,'hospital_list.xlsx')
data_hospital = pd.read_excel(data_file_path2)

# %%
data_hospital
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# # จัดการข้อมูล

# %%
new_alldb = data_alldb[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey']] # ตัดให้เหลือ column ที่ต้องการนำไปใช้
new_alldb
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#                   phone   site      time            urine   ov  \
# 0                   NaN    NaN       NaN              NaN  NaN
# 1            iPhone10,4  05310  10:50:32              NaN  NaN
# 2                   NaN    NaN       NaN              NaN  NaN
# 3            iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)    0
# 4            iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)  NaN
# ...                 ...    ...       ...              ...  ...
# 40030        iPhone13,4  01234       NaN              NaN  NaN
# 40031        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)    2
# 40032        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)    1
# 40033  Samsung SM-A115F  01234       NaN              NaN  NaN
# 40034  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)    1
#
#                  PartitionKey
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 40030     เกษศิรินทร์  ไชยลาภ
# 40031  เถลิงเกียรติ เสริฐเลิศ
# 40032                    เสรี
# 40033                    เสรี
# 40034                    เสรี
#
# [40035 rows x 9 columns]

# %%
new_alldb.isnull().sum() # เช็คค่า missing
# Out:
# user            762
# RowKey            1
# date            554
# phone             3
# site             99
# time            557
# urine           253
# ov              364
# PartitionKey    185
# dtype: int64

# %%
drop_alldb = new_alldb.dropna() # จัดการค่า missing โดยการ drop ทิ้งไป
drop_alldb
# Out:
#          user                                RowKey        date  \
# 185     85879                        shmpdrmtgc.png  2022-03-24
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 40013   ttest                        crqcufokmn.png  2022-02-21
# 40014   ttest                        gzxgflnowr.png  2022-02-21
# 40016     xxx                        jytlopevha.png  2022-02-17
# 40022     yyy                        ivccsksowb.png  2022-02-17
# 40023     zzz                        psudrnccsh.png  2022-02-17
#
#                    phone   site      time            urine ov PartitionKey
# 185         OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# 186           iPhone11,8  04312  09:45:28  ปกติ (เหลืองใส)  0       0-1528
# 187           iPhone11,8  04312  10:06:45  ปกติ (เหลืองใส)  0       0-1544
# 188           iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0         0000
# 190    Xiaomi 21081111RG  13777  16:31:45  ปกติ (เหลืองใส)  0        00000
# ...                  ...    ...       ...              ... ..          ...
# 40013   Samsung SM-G998B   test  14:23:45             ขุ่น  2         x001
# 40014   Samsung SM-G998B   test  14:23:43             ขุ่น  2         x001
# 40016   Samsung SM-N950F    xxx  00:01:06  ปกติ (เหลืองใส)  3          xxx
# 40022   Samsung SM-N950F    yyy  08:41:05   มีเม็ดเลือดแดง  2          yyy
# 40023   Samsung SM-N950F    zzz  08:41:04          มีตะกอน  2          zzz
#
# [38663 rows x 9 columns]

# %%
# เช็คข้อมูลหลังจากการ drop ว่าหายไปกี่เปอร์เซ็นต์
removes = new_alldb.shape[0] - drop_alldb.shape[0]
print(f'size before drop = {new_alldb.shape[0]}')
print(f'size after drop = {drop_alldb.shape[0]}')
print(f'% from drop = {(removes/new_alldb.shape[0])*100}')
# Out:
# size before drop = 40035
# size after drop = 38663
# % from drop = 3.427001373797927

# %% [markdown]
# ## จัดการให้ค่า site เป็นตัวเลข 5 หลัก(ตัวเลขเท่านั้น)

# %%
set(drop_alldb['site']) # set ดูค่าที่เก็บไว้
# Out:
# {' 0502',
#  '00004',
#  '00006',
#  '00007',
#  '00008',
#  '00012',
#  '00016',
#  '00017',
#  '00018',
#  '00027',
#  '00028',
#  '00040',
#  '00052',
#  '00055',
#  '00061',
#  '00069',
#  '00070',
#  '00071',
#  '00081',
#  '00082',
#  '00090',
#  '00094',
#  '00096',
#  '00108',
#  '00109',
#  '00115',
#  '00120',
#  '00122',
#  '00127',
#  '00163',
#  '00164',
#  '00165',
#  '00166',
#  '00169',
#  '00170',
#  '00171',
#  '00173',
#  '00174',
#  '00176',
#  '00177',
#  '00178',
#  '00179',
#  '00180',
#  '00182',
#  '00185',
#  '00186',
#  '00187',
#  '00189',
#  '00190',
#  '00191',
#  '00192',
#  '00193',
#  '00194',
#  '00195',
#  '00196',
#  '00197',
#  '00198',
#  '00200',
#  '00202',
#  '00204',
#  '00205',
#  '00206',
#  '00207',
#  '00209',
#  '00213',
#  '00214',
#  '00217',
#  '00218',
#  '00219',
#  '00229',
#  '00232',
#  '00235',
#  '00240',
#  '00247',
#  '00266',
#  '00271',
#  '00279',
#  '00323',
#  '00331',
#  '00333',
#  '00346',
#  '00348',
#  '00381',
#  '00382',
#  '00385',
#  '00387',
#  '00388',
#  '00389',
#  '00390',
#  '00391',
#  '00394',
#  '00397',
#  '00400',
#  '00401',
#  '00404',
#  '00406',
#  '00408',
#  '00410',
#  '00411',
#  '00412',
#  '00413',
#  '00414',
#  '00415',
#  '00512',
#  '00513',
#  '00579',
#  '00580',
#  '00956',
#  '01151',
#  '02038',
#  '02414',
#  '02536',
#  '02759',
#  '03432',
#  '03616',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '043.1',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
#  '04337',
#  '04347',
#  '04348',
#  '04349',
#  '04351',
#  '04352',
#  '04355',
#  '04374',
#  '04376',
#  '04380',
#  '04384',
#  '04387',
#  '04388',
#  '04390',
#  '04391',
#  '04396',
#  '04399',
#  '04401',
#  '04402',
#  '04403',
#  '04404',
#  '04405',
#  '04406',
#  '04407',
#  '04408',
#  '04433',
#  '04434',
#  '04435',
#  '04436',
#  '04437',
#  '04438',
#  '04441',
#  '04443',
#  '04455',
#  '04456',
#  '04457',
#  '04458',
#  '04475',
#  '04478',
#  '04558',
#  '04936',
#  '04968',
#  '04970',
#  '04971',
#  '04973',
#  '04974',
#  '04977',
#  '04980',
#  '04981',
#  '04982',
#  '04983',
#  '04984',
#  '04985',
#  '04986',
#  '04989',
#  '04990',
#  '04992',
#  '04993',
#  '04994',
#  '04995',
#  '04996',
#  '04997',
#  '04999',
#  '05000',
#  '05001',
#  '05002',
#  '05003',
#  '05004',
#  '05005',
#  '05006',
#  '05007',
#  '05008',
#  '05009',
#  '05010',
#  '05011',
#  '05012',
#  '05013',
#  '05015',
#  '05016',
#  '05019',
#  '05021',
#  '05022',
#  '05023',
#  '05024',
#  '05025',
#  '05026',
#  '05027',
#  '05028',
#  '05029',
#  '05032',
#  '05033',
#  '05034',
#  '05035',
#  '05038',
#  '05040',
#  '05042',
#  '05044',
#  '05045',
#  '05047',
#  '05048',
#  '05049',
#  '05052',
#  '05054',
#  '05055',
#  '05058',
#  '05059',
#  '05060',
#  '05061',
#  '05062',
#  '05063',
#  '05064',
#  '05065',
#  '05066',
#  '05067',
#  '05068',
#  '05069',
#  '05072',
#  '05074',
#  '05075',
#  '05077',
#  '05079',
#  '05080',
#  '05081',
#  '05082',
#  '05083',
#  '05084',
#  '05086',
#  '05087',
#  '05087\n',
#  '05088',
#  '05090',
#  '05091',
#  '05094',
#  '05097',
#  '05098',
#  '05100',
#  '05101',
#  '05102',
#  '05103',
#  '05107',
#  '05111',
#  '05112',
#  '05113',
#  '05115',
#  '05116',
#  '05117',
#  '05119',
#  '05120',
#  '05123',
#  '05125',
#  '05126',
#  '05128',
#  '05129',
#  '05131',
#  '05132',
#  '05133',
#  '05135',
#  '05136',
#  '05141',
#  '05143',
#  '05144',
#  '05146',
#  '05147',
#  '05152',
#  '05154',
#  '05157',
#  '05158',
#  '05162',
#  '05166',
#  '05172',
#  '05173',
#  '05175',
#  '05177',
#  '05178',
#  '05180',
#  '05181',
#  '05182',
#  '05185',
#  '05187',
#  '05188',
#  '05192',
#  '05193',
#  '05194',
#  '05195',
#  '05196',
#  '05198',
#  '05200',
#  '05203',
#  '05205',
#  '05207',
#  '05210',
#  '05211',
#  '05213',
#  '05214',
#  '05215',
#  '05219',
#  '05220',
#  '05222',
#  '05223',
#  '05224',
#  '05225',
#  '05226',
#  '05228',
#  '05229',
#  '05233',
#  '05236',
#  '05237',
#  '05238',
#  '05240',
#  '05241',
#  '05242',
#  '05244',
#  '05245',
#  '05246',
#  '05247',
#  '05248',
#  '05249',
#  '05250',
#  '05250\n',
#  '05251',
#  '05252',
#  '05253',
#  '05254',
#  '05255',
#  '05256',
#  '05257',
#  '05258',
#  '05259',
#  '05260',
#  '05261',
#  '05264',
#  '05265',
#  '05291',
#  '05298',
#  '05300',
#  '05304',
#  '05310',
#  '05311',
#  '05312',
#  '05313',
#  '05314',
#  '05315',
#  '05316',
#  '05322',
#  '05323',
#  '05324',
#  '05325',
#  '05327',
#  '05328',
#  '05332',
#  '05335',
#  '05337',
#  '05338',
#  '05339',
#  '05340',
#  '05343',
#  '05344',
#  '05345',
#  '05346',
#  '05349',
#  '05350',
#  '05350ยอ',
#  '05351',
#  '05352',
#  '05354',
#  '05355',
#  '05356',
#  '05357',
#  '05358',
#  '05359',
#  '05360',
#  '05361',
#  '05363',
#  '05365',
#  '05366',
#  '05367',
#  '05368',
#  '05370',
#  '05371',
#  '05373',
#  '05378',
#  '05386',
#  '05391',
#  '05392',
#  '05393',
#  '05394',
#  '05395',
#  '05396',
#  '05399',
#  '05413',
#  '05414',
#  '05415',
#  '05416',
#  '05418',
#  '05419',
#  '05422',
#  '05423',
#  '05424',
#  '05425',
#  '05428',
#  '05431',
#  '05432',
#  '05433',
#  '05434',
#  '05435',
#  '05436',
#  '05437',
#  '05439',
#  '05440',
#  '05441',
#  '05442',
#  '05541',
#  '06238',
#  '06251',
#  '06253',
#  '06254',
#  '06255',
#  '06256',
#  '06257',
#  '06259',
#  '06260',
#  '06261',
#  '06263',
#  '06265',
#  '06267',
#  '06268',
#  '06270',
#  '06271',
#  '06272',
#  '06273',
#  '06274',
#  '06275',
#  '06276',
#  '06277',
#  '06278',
#  '06279',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '06521',
#  '08485',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11111',
#  '11111111',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11740',
#  '11748',
#  '11749',
#  '11800',
#  '11887',
#  '13777',
#  '13777t',
#  '13937',
#  '13941',
#  '13943',
#  '13943\n\n',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '13987',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '20510',
#  '22222',
#  '24622',
#  '24650',
#  '27988',
#  '27990',
#  '27998',
#  '28017',
#  '28691',
#  '28789',
#  '33333',
#  '44902',
#  '45972',
#  '49741',
#  '50210',
#  '5271',
#  '55555',
#  '66666',
#  '75757',
#  '88888',
#  '97255',
#  '99795',
#  '99999',
#  'aaa',
#  'bbb',
#  'ccc',
#  'eee',
#  'fff',
#  'ggg',
#  'hhh',
#  'iii',
#  'jjj',
#  'kkk',
#  'lll',
#  'mmm',
#  'ppp',
#  'qqq',
#  'rrr',
#  'sss',
#  'test',
#  'ttt',
#  'uuu',
#  'vvv',
#  'www',
#  'xxx',
#  'yyy',
#  'zzz'}

# %%
drop_alldb = drop_alldb[(drop_alldb['site'].astype(str).str.isdigit()) & (drop_alldb['site'].str.len() == 5)] # เช็ค type ของข้อมูลโดยใช้ str.isdigit() และทำการเลือกข้อมูลที่เป็นตัวเลข 5 หลักเท่านั้น
drop_alldb
# Out:
#          user                                RowKey        date  \
# 185     85879                        shmpdrmtgc.png  2022-03-24
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 39812   99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11
# 39813   99999                        lnlohgqckf.png  2022-03-10
# 39814   99999                        vkdocpmjiv.png  2022-03-10
# 39815   99999                        vrvyfnvayq.png  2022-03-10
# 39816   99999                        zuhbtvyrce.png  2022-03-10
#
#                    phone   site      time                 urine ov  \
# 185         OPPO CPH2293  05194  13:08:39               มีตะกอน  0
# 186           iPhone11,8  04312  09:45:28       ปกติ (เหลืองใส)  0
# 187           iPhone11,8  04312  10:06:45       ปกติ (เหลืองใส)  0
# 188           iPhone13,1  04999  14:22:22       ปกติ (เหลืองใส)  0
# 190    Xiaomi 21081111RG  13777  16:31:45       ปกติ (เหลืองใส)  0
# ...                  ...    ...       ...                   ... ..
# 39812         iPhone14,2  99999  11:36:34                  ขุ่น  1
# 39813   Samsung SM-G998B  99999  18:10:29               มีตะกอน  0
# 39814   Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง  1
# 39815   Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)  1
# 39816   Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)  1
#
#       PartitionKey
# 185           0000
# 186         0-1528
# 187         0-1544
# 188           0000
# 190          00000
# ...            ...
# 39812        99999
# 39813        99999
# 39814        99999
# 39815        99999
# 39816        99999
#
# [38359 rows x 9 columns]

# %%
new_hospital = data_hospital[['hcode','name','zone_code','zone_name','provincecode','province','amphurcode','amphur','tamboncode','tambon']] # ตัดให้เหลือ column ที่ต้องการนำไปใช้
new_hospital
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ
# 1          เมืองนนทบุรี         4.0   บางกระสอ
# 2         เมืองปทุมธานี         1.0    บางปรอก
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ
# ...                 ...         ...        ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ
# 17099           กุยบุรี         1.0    กุยบุรี
# 17100           วัดเพลง         3.0    วัดเพลง
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า
# 17102             บางแพ         2.0    วังเย็น
#
# [17103 rows x 10 columns]

# %%
new_hospital.isnull().sum() # เช็คค่า missing
# Out:
# hcode             0
# name              1
# zone_code         0
# zone_name         4
# provincecode      1
# province          0
# amphurcode        2
# amphur            2
# tamboncode      168
# tambon          209
# dtype: int64

# %%
drop_hospital = new_hospital.dropna() # จัดการค่า missing โดยการ drop 
drop_hospital
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ
# 1          เมืองนนทบุรี         4.0   บางกระสอ
# 2         เมืองปทุมธานี         1.0    บางปรอก
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ
# ...                 ...         ...        ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ
# 17099           กุยบุรี         1.0    กุยบุรี
# 17100           วัดเพลง         3.0    วัดเพลง
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า
# 17102             บางแพ         2.0    วังเย็น
#
# [16890 rows x 10 columns]

# %%
# เช็คข้อมูลหลังจากการ drop ว่าหายไปกี่เปอร์เซ็นต์
removes = new_hospital.shape[0] - drop_hospital.shape[0]
print(f'size before drop = {new_hospital.shape[0]}')
print(f'size after drop = {drop_hospital.shape[0]}')
print(f'% from drop = {(removes/new_hospital.shape[0])*100}')
# Out:
# size before drop = 17103
# size after drop = 16890
# % from drop = 1.245395544641291

# %%
set(drop_hospital['hcode']) # set ดูค่าที่เก็บไว้
# Out:
# {'02261',
#  '23608',
#  '04803',
#  '03001',
#  '26616',
#  '05085',
#  '12072',
#  '03542',
#  '77762',
#  '24264',
#  '05830',
#  '08356',
#  '08599',
#  '18093',
#  '24157',
#  '25025',
#  '06704',
#  '06225',
#  '09528',
#  '99826',
#  '14029',
#  '06790',
#  '09650',
#  '00275',
#  '02451',
#  '27066',
#  '07233',
#  '05300',
#  '14839',
#  '23724',
#  '03633',
#  '04301',
#  '16923',
#  '23924',
#  '25703',
#  '13993',
#  '11162',
#  '00776',
#  '10112',
#  '25802',
#  '07243',
#  '01032',
#  '07769',
#  '08669',
#  '27456',
#  '23607',
#  '02657',
#  '19354',
#  '13916',
#  '13994',
#  '07714',
#  '17458',
#  '06537',
#  '12261',
#  '11741',
#  '27480',
#  '07995',
#  '04599',
#  '15667',
#  '00015',
#  '02358',
#  '24953',
#  '02118',
#  '27365',
#  '09889',
#  '03560',
#  '06557',
#  '05872',
#  '06618',
#  '04402',
#  '01157',
#  '09666',
#  '07252',
#  '04813',
#  '00312',
#  '06567',
#  '01021',
#  '02822',
#  '08511',
#  '10179',
#  '21438',
#  '07265',
#  '03602',
#  '77741',
#  '11047',
#  '24419',
#  '28835',
#  '10439',
#  '12230',
#  '21519',
#  '02229',
#  '03796',
#  '04598',
#  '01439',
#  '06200',
#  '77770',
#  '06677',
#  '24143',
#  '25994',
#  '07535',
#  '16313',
#  '21708',
#  '00310',
#  '05346',
#  '05813',
#  '04897',
#  '06395',
#  '10959',
#  '14691',
#  '04235',
#  '08231',
#  '08359',
#  '11376',
#  '00911',
#  '23822',
#  '10405',
#  '08163',
#  '19338',
#  '03357',
#  '10972',
#  ...}

# %% [markdown]
# ## รวมตารางข้อมูล alldb และ hospital เข้าด้วยกัน โดยใช้การ merge

# %%
data = drop_alldb.merge(drop_hospital,how='left',left_on='site',right_on='hcode') # เชื่อมตารางโดยตารางทางซ้ายเป็น alldb มี key คือ site เชื่อมกับ hospital มี key คือ hcode
data
# Out:
#          user                                RowKey        date  \
# 0       85879                        shmpdrmtgc.png  2022-03-24
# 1      45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 2      45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 3       27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 4       06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 38354   99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11
# 38355   99999                        lnlohgqckf.png  2022-03-10
# 38356   99999                        vkdocpmjiv.png  2022-03-10
# 38357   99999                        vrvyfnvayq.png  2022-03-10
# 38358   99999                        zuhbtvyrce.png  2022-03-10
#
#                    phone   site      time                 urine ov  \
# 0           OPPO CPH2293  05194  13:08:39               มีตะกอน  0
# 1             iPhone11,8  04312  09:45:28       ปกติ (เหลืองใส)  0
# 2             iPhone11,8  04312  10:06:45       ปกติ (เหลืองใส)  0
# 3             iPhone13,1  04999  14:22:22       ปกติ (เหลืองใส)  0
# 4      Xiaomi 21081111RG  13777  16:31:45       ปกติ (เหลืองใส)  0
# ...                  ...    ...       ...                   ... ..
# 38354         iPhone14,2  99999  11:36:34                  ขุ่น  1
# 38355   Samsung SM-G998B  99999  18:10:29               มีตะกอน  0
# 38356   Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง  1
# 38357   Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)  1
# 38358   Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)  1
#
#       PartitionKey  hcode                                               name  \
# 0             0000  05194  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองหว้า ตำบลกก...
# 1           0-1528  04312                  โรงพยาบาลส่งเสริมสุขภาพตำบลสีชมพู
# 2           0-1544  04312                  โรงพยาบาลส่งเสริมสุขภาพตำบลสีชมพู
# 3             0000  04999              โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเปลือย
# 4            00000  13777            โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น
# ...            ...    ...                                                ...
# 38354        99999    NaN                                                NaN
# 38355        99999    NaN                                                NaN
# 38356        99999    NaN                                                NaN
# 38357        99999    NaN                                                NaN
# 38358        99999    NaN                                                NaN
#
#        zone_code             zone_name  provincecode   province  amphurcode  \
# 0            7.0  สาขาพื้นที่(ขอนแก่น)          45.0   ร้อยเอ็ด         9.0
# 1            7.0  สาขาพื้นที่(ขอนแก่น)          40.0    ขอนแก่น         6.0
# 2            7.0  สาขาพื้นที่(ขอนแก่น)          40.0    ขอนแก่น         6.0
# 3            7.0  สาขาพื้นที่(ขอนแก่น)          44.0  มหาสารคาม         6.0
# 4            7.0  สาขาพื้นที่(ขอนแก่น)          40.0    ขอนแก่น         1.0
# ...          ...                   ...           ...        ...         ...
# 38354        NaN                   NaN           NaN        NaN         NaN
# 38355        NaN                   NaN           NaN        NaN         NaN
# 38356        NaN                   NaN           NaN        NaN         NaN
# 38357        NaN                   NaN           NaN        NaN         NaN
# 38358        NaN                   NaN           NaN        NaN         NaN
#
#              amphur  tamboncode   tambon
# 0           หนองพอก         4.0  กกโพธิ์
# 1            สีชมพู         1.0   สีชมพู
# 2            สีชมพู         1.0   สีชมพู
# 3             บรบือ        19.0   หนองโก
# 4      เมืองขอนแก่น         1.0  ในเมือง
# ...             ...         ...      ...
# 38354           NaN         NaN      NaN
# 38355           NaN         NaN      NaN
# 38356           NaN         NaN      NaN
# 38357           NaN         NaN      NaN
# 38358           NaN         NaN      NaN
#
# [38359 rows x 19 columns]

# %%
data.isnull().sum() # เช็คค่า missing
# Out:
# user             0
# RowKey           0
# date             0
# phone            0
# site             0
# time             0
# urine            0
# ov               0
# PartitionKey     0
# hcode           84
# name            84
# zone_code       84
# zone_name       84
# provincecode    84
# province        84
# amphurcode      84
# amphur          84
# tamboncode      84
# tambon          84
# dtype: int64

# %%
drop_data = data.dropna() # จัดการค่า missing โดยการ drop
drop_data
# Out:
#          user                                RowKey        date  \
# 0       85879                        shmpdrmtgc.png  2022-03-24
# 1      45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 2      45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 3       27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 4       06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 38338   76331                        pvpiawlexb.png  2022-02-23
# 38339   68317                        rtutxrlbam.png  2022-02-23
# 38340   68317                        dmuragqwza.png  2022-02-23
# 38341   68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663  2022-03-24
# 38342   99771  E04D3D60-B916-40A1-AE77-91CCD89DD084  2022-03-31
#
#                    phone   site      time            urine ov PartitionKey  \
# 0           OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# 1             iPhone11,8  04312  09:45:28  ปกติ (เหลืองใส)  0       0-1528
# 2             iPhone11,8  04312  10:06:45  ปกติ (เหลืองใส)  0       0-1544
# 3             iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0         0000
# 4      Xiaomi 21081111RG  13777  16:31:45  ปกติ (เหลืองใส)  0        00000
# ...                  ...    ...       ...              ... ..          ...
# 38338   Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1           92
# 38339   Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2          976
# 38340   Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2          983
# 38341         iPhone11,8  11088  10:25:32  ปกติ (เหลืองใส)  1        99444
# 38342         iPhone10,5  05396  11:03:40  ปกติ (เหลืองใส)  0        99771
#
#        hcode                                               name  zone_code  \
# 0      05194  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองหว้า ตำบลกก...        7.0
# 1      04312                  โรงพยาบาลส่งเสริมสุขภาพตำบลสีชมพู        7.0
# 2      04312                  โรงพยาบาลส่งเสริมสุขภาพตำบลสีชมพู        7.0
# 3      04999              โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเปลือย        7.0
# 4      13777            โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น        7.0
# ...      ...                                                ...        ...
# 38338  05258  โรงพยาบาลส่งเสริมสุขภาพตำบลหนองตาโฮม ตำบลขี้เหล็ก        7.0
# 38339  28017                                      โรงพยาบาลนาคู        7.0
# 38340  28017                                      โรงพยาบาลนาคู        7.0
# 38341  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38342  05396             โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านสูงเนิน        7.0
#
#                   zone_name  provincecode   province  amphurcode  \
# 0      สาขาพื้นที่(ขอนแก่น)          45.0   ร้อยเอ็ด         9.0
# 1      สาขาพื้นที่(ขอนแก่น)          40.0    ขอนแก่น         6.0
# 2      สาขาพื้นที่(ขอนแก่น)          40.0    ขอนแก่น         6.0
# 3      สาขาพื้นที่(ขอนแก่น)          44.0  มหาสารคาม         6.0
# 4      สาขาพื้นที่(ขอนแก่น)          40.0    ขอนแก่น         1.0
# ...                     ...           ...        ...         ...
# 38338  สาขาพื้นที่(ขอนแก่น)          45.0   ร้อยเอ็ด        14.0
# 38339  สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        16.0
# 38340  สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        16.0
# 38341  สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38342  สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        10.0
#
#              amphur  tamboncode        tambon
# 0           หนองพอก         4.0       กกโพธิ์
# 1            สีชมพู         1.0        สีชมพู
# 2            สีชมพู         1.0        สีชมพู
# 3             บรบือ        19.0        หนองโก
# 4      เมืองขอนแก่น         1.0       ในเมือง
# ...             ...         ...           ...
# 38338     อาจสามารถ         9.0      ขี้เหล็ก
# 38339          นาคู         1.0          นาคู
# 38340          นาคู         1.0          นาคู
# 38341      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38342        คำม่วง         9.0       เนินยาง
#
# [38275 rows x 19 columns]

# %%
# เช็คข้อมูลหลังจากการ drop ว่าหายไปกี่เปอร์เซ็นต์
removes = data.shape[0] - drop_data.shape[0]
print(f'size before drop = {data.shape[0]}')
print(f'size after drop = {drop_data.shape[0]}')
print(f'% from drop = {(removes/data.shape[0])*100}')
# Out:
# size before drop = 38359
# size after drop = 38275
# % from drop = 0.21898381083969862

# %% [markdown]
# ## เปลี่ยน type ข้อมูล

# %%
drop_data.info() # เช็ค type ข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38275 entries, 0 to 38342
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user          38275 non-null  object
#  1   RowKey        38275 non-null  object
#  2   date          38275 non-null  object
#  3   phone         38275 non-null  object
#  4   site          38275 non-null  object
#  5   time          38275 non-null  object
#  6   urine         38275 non-null  object
#  7   ov            38275 non-null  object
#  8   PartitionKey  38275 non-null  object
#  9   hcode         38275 non-null  object
#  10  name          38275 non-null  object
#  11  zone_code     38275 non-null  float64
#  12  zone_name     38275 non-null  object
#  13  provincecode  38275 non-null  float64
#  14  province      38275 non-null  object
#  15  amphurcode    38275 non-null  float64
#  16  amphur        38275 non-null  object
#  17  tamboncode    38275 non-null  float64
#  18  tambon        38275 non-null  object
# dtypes: float64(4), object(15)
# memory usage: 5.8+ MB

# %%
# ทำการเปลี่ย type ของข้อมูล
drop_data['RowKey'] = drop_data['RowKey'].astype('string')
drop_data['phone'] = drop_data['phone'].astype('string')
drop_data['urine'] = drop_data['urine'].astype('string')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
#
#  '00148',
#  '00194',
#  '02897',
#  '99992',
#  '96630',
#  '00308',
#  '49178',
#  '00131',
#  '64081',
#  '85433',
#  '10724',
#  '51568',
#  '3450101576642',
#  '3450101325593',
#  '42120',
#  '04388',
#  '50802',
#  '11198',
#  '32999',
#  '22455',
#  '11165',
#  '40828',
#  '27503',
#  '17132',
#  '71921',
#  '00157',
#  '81409',
#  '26043',
#  '29391',
#  '76339',
#  '32581',
#  '01721',
#  '00208',
#  '31143',
#  '02217',
#  '00313',
#  '89290',
#  '22692',
#  '51892',
#  '01024',
#  '82822',
#  '00121',
#  '74103',
#  '95161',
#  '10264',
#  '99376',
#  '67093',
#  '19130',
#  '08971',
#  '00073',
#  '04431',
#  '14884',
#  '34169',
#  '75841',
#  '55865',
#  '23596',
#  '16725',
#  '94494',
#  '58870',
#  '05019',
#  '98703',
#  '00166',
#  '38463',
#  '86774',
#  '00053',
#  '42228',
#  '72938',
#  '02579',
#  '46732',
#  '75835',
#  '7197',
#  '78251',
#  '59269',
#  '84493',
#  '75579',
#  '94392',
#  '08236',
#  '85737',
#  '61806',
#  '74367',
#  '39726',
#  '96760',
#  '73204',
#  '82582',
#  '28186',
#  '00120',
#  '50373',
#  '00045',
#  '22635',
#  '46520',
#  '85702',
#  '36362',
#  '30067',
#  '85934',
#  '72225',
#  '00215',
#  '20827',
#  '96099',
#  '62768',
#  '46291',
#  '00154',
#  '42173',
#  '44888',
#  '56044',
#  '19201',
#  '14771',
#  '03558',
#  '03087',
#  '79834',
#  '14891',
#  '54781',
#  '14390',
#  '34409',
#  '00182',
#  '01009',
#  '75061',
#  '87468',
#  '03381',
#  '00293',
#  '68162',
#  '3450100543961',
#  '74891',
#  '09259',
#  '32082',
#  '21378',
#  '00174',
#  '73772',
#  '44902',
#  '04221',
#  '32831',
#  ...}

# %%
drop_data = drop_data[(drop_data['user'].astype(str).str.isdigit()) & (drop_data['user'].str.len() == 5)] # เช็ค type ของข้อมูลโดยใช้ str.isdigit() และทำการเลือกข้อมูลที่เป็นตัวเลข 5 หลักเท่านั้น
drop_data
# Out:
#         user                                RowKey        date  \
# 0      85879                        shmpdrmtgc.png  2022-03-24
# 3      27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 4      06223                        kfpwuaqldj.png  2022-03-23
# 5      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30
# 6      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30
# ...      ...                                   ...         ...
# 38338  76331                        pvpiawlexb.png  2022-02-23
# 38339  68317                        rtutxrlbam.png  2022-02-23
# 38340  68317                        dmuragqwza.png  2022-02-23
# 38341  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663  2022-03-24
# 38342  99771  E04D3D60-B916-40A1-AE77-91CCD89DD084  2022-03-31
#
#                    phone   site      time            urine ov PartitionKey  \
# 0           OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# 3             iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0         0000
# 4      Xiaomi 21081111RG  13777  16:31:45  ปกติ (เหลืองใส)  0        00000
# 5             iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4        00001
# 6             iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4        00001
# ...                  ...    ...       ...              ... ..          ...
# 38338   Samsung SM-G965U  05258  15:32:53  ปกติ (เหลืองใส)  1           92
# 38339   Samsung SM-A115F  28017  14:31:01  ปกติ (เหลืองใส)  2          976
# 38340   Samsung SM-A115F  28017  14:30:21  ปกติ (เหลืองใส)  2          983
# 38341         iPhone11,8  11088  10:25:32  ปกติ (เหลืองใส)  1        99444
# 38342         iPhone10,5  05396  11:03:40  ปกติ (เหลืองใส)  0        99771
#
#        hcode                                               name  zone_code  \
# 0      05194  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองหว้า ตำบลกก...        7.0
# 3      04999              โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเปลือย        7.0
# 4      13777            โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น        7.0
# 5      06307  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา        2.0
# 6      05328        โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์        7.0
# ...      ...                                                ...        ...
# 38338  05258  โรงพยาบาลส่งเสริมสุขภาพตำบลหนองตาโฮม ตำบลขี้เหล็ก        7.0
# 38339  28017                                      โรงพยาบาลนาคู        7.0
# 38340  28017                                      โรงพยาบาลนาคู        7.0
# 38341  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38342  05396             โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านสูงเนิน        7.0
#
#                    zone_name  provincecode   province  amphurcode  \
# 0       สาขาพื้นที่(ขอนแก่น)          45.0   ร้อยเอ็ด         9.0
# 3       สาขาพื้นที่(ขอนแก่น)          44.0  มหาสารคาม         6.0
# 4       สาขาพื้นที่(ขอนแก่น)          40.0    ขอนแก่น         1.0
# 5      สาขาพื้นที่(พิษณุโลก)          53.0  อุตรดิตถ์         7.0
# 6       สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        18.0
# ...                      ...           ...        ...         ...
# 38338   สาขาพื้นที่(ขอนแก่น)          45.0   ร้อยเอ็ด        14.0
# 38339   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        16.0
# 38340   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        16.0
# 38341   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38342   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        10.0
#
#              amphur  tamboncode        tambon
# 0           หนองพอก         4.0       กกโพธิ์
# 3             บรบือ        19.0        หนองโก
# 4      เมืองขอนแก่น         1.0       ในเมือง
# 5             พิชัย         2.0      บ้านดารา
# 6           ฆ้องชัย         3.0      โคกสะอาด
# ...             ...         ...           ...
# 38338     อาจสามารถ         9.0      ขี้เหล็ก
# 38339          นาคู         1.0          นาคู
# 38340          นาคู         1.0          นาคู
# 38341      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38342        คำม่วง         9.0       เนินยาง
#
# [37890 rows x 19 columns]

# %% [markdown]
# ## เปลี่ยน date เป็น YYYY-MM-DD

# %%
drop_data['date'] = pd.to_datetime(drop_data['date'],format="%Y/%m/%d") # เปลี่ยน format ของข้อมูลวันที่ให้อยู่ในรูปแบบเดียวกัน
drop_data[['date']]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             date
# 0     2022-03-24
# 3     2022-02-25
# 4     2022-03-23
# 5     2022-03-30
# 6     2022-03-30
# ...          ...
# 38338 2022-02-23
# 38339 2022-02-23
# 38340 2022-02-23
# 38341 2022-03-24
# 38342 2022-03-31
#
# [37890 rows x 1 columns]

# %% [markdown]
# ## เปลี่ยน time เป็น hh-mm-ss

# %%
drop_data['time'] = pd.to_datetime(drop_data['time'],format='%H:%M%:%S',errors='ignore') # เปลี่ยน format ของข้อมูลเวลาให้อยู่ในรูปแบบเดียวกัน
drop_data[['time']]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            time
# 0      13:08:39
# 3      14:22:22
# 4      16:31:45
# 5      14:46:08
# 6      15:27:45
# ...         ...
# 38338  15:32:53
# 38339  14:31:01
# 38340  14:30:21
# 38341  10:25:32
# 38342  11:03:40
#
# [37890 rows x 1 columns]

# %% [markdown]
# ## จัดการให้ค่า ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)

# %%
set(drop_data['ov']) # set ดูค่าที่เก็บไว้
# Out:
# {'0', '1', '2', '3', '4', 'ติดเชื้อ +2 '}

# %%
drop_data[drop_data['ov'] == 'ติดเชื้อ +2 '] # ดูว่า 'ติดเชื้อ +2 ' เป็นค่าที่เท่าไร
# Out:
#         user                                RowKey       date      phone  \
# 16413  87374  A838A03E-1327-4720-B689-FD29C78023FD 2022-03-07  iPhone8,2
#
#         site      time            urine            ov PartitionKey  hcode  \
# 16413  05237  11:50:47  ปกติ (เหลืองใส)  ติดเชื้อ +2         00187  05237
#
#                                                     name  zone_code  \
# 16413  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านจานเตย   ตำบลทุ...        7.0
#
#                   zone_name  provincecode  province  amphurcode      amphur  \
# 16413  สาขาพื้นที่(ขอนแก่น)          45.0  ร้อยเอ็ด        11.0  สุวรรณภูมิ
#
#        tamboncode    tambon
# 16413        13.0  ทุ่งกุลา

# %%
drop_data['ov'] = drop_data['ov'].drop(16413) # drop ค่า 'ติดเชื้อ +2 ' ทิ้ง
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
drop_data = drop_data.dropna(subset=['ov']) # จัดการค่า missing

# %%
set(drop_data['ov']) # เช็คค่าที่เก็บไว้
# Out:
# {'0', '1', '2', '3', '4'}

# %% [markdown]
# ## จัดการให้ค่า PartitionKey เป็นตัวเลข 5 หลัก(ตัวเลขเท่านั้น)

# %%
set(drop_data['PartitionKey']) # set ดูค่าที่เก็บไว้
# Out:
# {'02304',
#  '00028',
#  '06049',
#  '00011',
#  '03542',
#  '01544',
#  '02120',
#  '00212',
#  '02472',
#  '03133',
#  '05830',
#  '02653',
#  '02701',
#  '01167',
#  '00720',
#  '02784',
#  '02912',
#  '00275',
#  '02143',
#  '02451',
#  '02991',
#  '01424',
#  '03107',
#  '01248',
#  '00973',
#  '10996',
#  '01576',
#  '00776',
#  '01032',
#  '00146',
#  '01739',
#  '01199',
#  '02029',
#  '05991',
#  '02771',
#  '01738',
#  '02085',
#  '00333',
#  '01680',
#  '02976',
#  '00521',
#  '01957',
#  '01612',
#  '00838',
#  '01778',
#  '02808',
#  '00541',
#  '200',
#  '01725',
#  '00427',
#  '03197',
#  '08904',
#  '05780',
#  '01047',
#  '00608',
#  '02904',
#  '89',
#  '00032',
#  '00734',
#  '09011',
#  '00716',
#  '00819',
#  '00058',
#  '00270',
#  '01595',
#  '03221',
#  '00292',
#  '00370',
#  '00786',
#  '000102',
#  '00742',
#  '01251',
#  '01393',
#  '00532',
#  '01809',
#  '01897',
#  '03245',
#  '03255',
#  '00190',
#  '00119',
#  '01028',
#  '00957',
#  '03824',
#  '01910',
#  '04137',
#  '05981',
#  '01361',
#  '01069',
#  '01355',
#  '02195',
#  '06723',
#  '00495',
#  '08947',
#  '00632',
#  '01236',
#  '00337',
#  '01247',
#  '00470',
#  '00549',
#  '03168',
#  '04691',
#  '05974',
#  '09007',
#  '00526',
#  '00425',
#  '01585',
#  '03189',
#  '01975',
#  '03108',
#  '04623',
#  '193',
#  '00099',
#  '02929',
#  '01469',
#  '02883',
#  '01332',
#  '00768',
#  '00449',
#  '00852',
#  '08924',
#  '00126',
#  '02989',
#  '01652',
#  '01878',
#  '00006',
#  '00717',
#  '01100',
#  '02540',
#  '01381',
#  '02690',
#  '03220',
#  '05984',
#  '05350',
#  '00669',
#  '01579',
#  '02286',
#  '02532',
#  '00274',
#  '01828',
#  '02666',
#  '01907',
#  '01054',
#  '02624',
#  '00015',
#  '09016',
#  '00610',
#  '107',
#  '02199',
#  '02934',
#  '00942',
#  '05116',
#  '01157',
#  '00261',
#  '00103',
#  '00000',
#  '05957',
#  '04640',
#  '00345',
#  '01733',
#  '04813',
#  '00312',
#  '01021',
#  '02010',
#  '02822',
#  '05965',
#  '02202',
#  '00302',
#  '01453',
#  '03309',
#  '08996',
#  '02244',
#  '03548',
#  '00692',
#  '00342',
#  '03123',
#  '00010',
#  '02232',
#  '01439',
#  '06004',
#  '44147',
#  '01463',
#  '180',
#  '05114',
#  '00310',
#  '00268',
#  '02084',
#  '01097',
#  '02041',
#  '01146',
#  '02201',
#  '04753',
#  '00911',
#  '01557',
#  '06053',
#  '00462',
#  '00442',
#  '00317',
#  '02710',
#  '02790',
#  '10972',
#  '00897',
#  '01333',
#  '10971',
#  '00686',
#  '02945',
#  '05997',
#  '03059',
#  '00975',
#  '08477',
#  '01584',
#  '01479',
#  '03425',
#  '04674',
#  '00134',
#  '00685',
#  '00399',
#  '00149',
#  '01976',
#  '00992',
#  '01192',
#  '00503',
#  '03218',
#  '03106',
#  '04695',
#  '01309',
#  '01396',
#  '02672',
#  '00847',
#  '02147',
#  '02643',
#  '01253',
#  '02756',
#  '03304',
#  '0018',
#  '00548',
#  '00711',
#  '00429',
#  '01526',
#  '01273',
#  '00533',
#  '03137',
#  '04043',
#  '01134',
#  '00535',
#  '06008',
#  '09000',
#  '00067',
#  '02978',
#  '00635',
#  '01229',
#  '01349',
#  '03711',
#  '05223',
#  '05095',
#  '08960',
#  '00060',
#  '04673',
#  '03361',
#  '04793',
#  '02073',
#  '01545',
#  '01718',
#  '05976',
#  '01575',
#  '11111',
#  '01405',
#  '02019',
#  '04253',
#  '00506',
#  '02741',
#  '05097',
#  '01231',
#  '00837',
#  '04660',
#  '02819',
#  '05228',
#  '04637',
#  '00139',
#  '02594',
#  '00257',
#  '01884',
#  '00480',
#  '03179',
#  '00048',
#  '00536',
#  '01234',
#  '00900',
#  '04974',
#  '00112',
#  '00366',
#  '03373',
#  '00783',
#  '04811',
#  '05118',
#  '02892',
#  '01281',
#  '00745',
#  '02399',
#  '00729',
#  '01165',
#  '03132',
#  '02664',
#  '03299',
#  '09042',
#  '03225',
#  '02320',
#  '00195',
#  '01790',
#  '02839',
#  '04694',
#  '05996',
#  '01392',
#  '02599',
#  '01560',
#  '01533',
#  '02404',
#  '00435',
#  '08991',
#  '01342',
#  '05382',
#  '00633',
#  '00167',
#  '02151',
#  '00797',
#  '03593',
#  '00712',
#  '00255',
#  '00653',
#  '01096',
#  '01732',
#  '04682',
#  '01567',
#  '10968',
#  '00646',
#  '02953',
#  '10981',
#  '01818',
#  '01548',
#  '02750',
#  ...}

# %%
drop_data = drop_data[(drop_data['PartitionKey'].astype(str).str.isdigit()) & (drop_data['PartitionKey'].str.len() == 5)] # เช็ค type ของข้อมูลโดยใช้ str.isdigit() และทำการเลือกข้อมูลที่เป็นตัวเลข 5 หลักเท่านั้น
drop_data
# Out:
#         user                                RowKey       date  \
# 4      06223                        kfpwuaqldj.png 2022-03-23
# 5      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 6      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 7      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 8      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 38335  68768  B7F36631-D2C4-4EB5-852D-790BFAFDFD71 2022-03-24
# 38336  68768  899A7591-50C9-40BC-9746-A831A08DE980 2022-03-24
# 38337  68768  BF39F27C-1B43-4C97-A034-D7A579BED2B6 2022-03-24
# 38341  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663 2022-03-24
# 38342  99771  E04D3D60-B916-40A1-AE77-91CCD89DD084 2022-03-31
#
#                    phone   site      time            urine ov PartitionKey  \
# 4      Xiaomi 21081111RG  13777  16:31:45  ปกติ (เหลืองใส)  0        00000
# 5             iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4        00001
# 6             iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4        00001
# 7             iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3        00001
# 8              iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3        00001
# ...                  ...    ...       ...              ... ..          ...
# 38335         iPhone11,8  11088  10:30:22  ปกติ (เหลืองใส)  2        89170
# 38336         iPhone11,8  11088  10:29:37  ปกติ (เหลืองใส)  0        90470
# 38337         iPhone11,8  11088  10:24:40  ปกติ (เหลืองใส)  1        91123
# 38341         iPhone11,8  11088  10:25:32  ปกติ (เหลืองใส)  1        99444
# 38342         iPhone10,5  05396  11:03:40  ปกติ (เหลืองใส)  0        99771
#
#        hcode                                               name  zone_code  \
# 4      13777            โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น        7.0
# 5      06307  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา        2.0
# 6      05328        โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์        7.0
# 7      06302                 โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง        2.0
# 8      05059              โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่        7.0
# ...      ...                                                ...        ...
# 38335  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38336  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38337  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38341  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38342  05396             โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านสูงเนิน        7.0
#
#                    zone_name  provincecode   province  amphurcode  \
# 4       สาขาพื้นที่(ขอนแก่น)          40.0    ขอนแก่น         1.0
# 5      สาขาพื้นที่(พิษณุโลก)          53.0  อุตรดิตถ์         7.0
# 6       สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        18.0
# 7      สาขาพื้นที่(พิษณุโลก)          53.0  อุตรดิตถ์         5.0
# 8       สาขาพื้นที่(ขอนแก่น)          44.0  มหาสารคาม        10.0
# ...                      ...           ...        ...         ...
# 38335   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38336   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38337   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38341   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38342   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        10.0
#
#              amphur  tamboncode        tambon
# 4      เมืองขอนแก่น         1.0       ในเมือง
# 5             พิชัย         2.0      บ้านดารา
# 6           ฆ้องชัย         3.0      โคกสะอาด
# 7            ฟากท่า         4.0       สองห้อง
# 8             นาดูน         6.0         หัวดง
# ...             ...         ...           ...
# 38335      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38336      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38337      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38341      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38342        คำม่วง         9.0       เนินยาง
#
# [37820 rows x 19 columns]

# %%
drop_data.isnull().any() # เช็คค่า missing
# Out:
# user            False
# RowKey          False
# date            False
# phone           False
# site            False
# time            False
# urine           False
# ov              False
# PartitionKey    False
# hcode           False
# name            False
# zone_code       False
# zone_name       False
# provincecode    False
# province        False
# amphurcode      False
# amphur          False
# tamboncode      False
# tambon          False
# dtype: bool

# %%
drop_data
# Out:
#         user                                RowKey       date  \
# 4      06223                        kfpwuaqldj.png 2022-03-23
# 5      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30
# 6      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30
# 7      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30
# 8      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29
# ...      ...                                   ...        ...
# 38335  68768  B7F36631-D2C4-4EB5-852D-790BFAFDFD71 2022-03-24
# 38336  68768  899A7591-50C9-40BC-9746-A831A08DE980 2022-03-24
# 38337  68768  BF39F27C-1B43-4C97-A034-D7A579BED2B6 2022-03-24
# 38341  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663 2022-03-24
# 38342  99771  E04D3D60-B916-40A1-AE77-91CCD89DD084 2022-03-31
#
#                    phone   site      time            urine ov PartitionKey  \
# 4      Xiaomi 21081111RG  13777  16:31:45  ปกติ (เหลืองใส)  0        00000
# 5             iPhone12,3  06307  14:46:08  ปกติ (เหลืองใส)  4        00001
# 6             iPhone14,3  05328  15:27:45  ปกติ (เหลืองใส)  4        00001
# 7             iPhone13,4  06302  10:16:46  ปกติ (เหลืองใส)  3        00001
# 8              iPhone9,4  05059  12:26:38  ปกติ (เหลืองใส)  3        00001
# ...                  ...    ...       ...              ... ..          ...
# 38335         iPhone11,8  11088  10:30:22  ปกติ (เหลืองใส)  2        89170
# 38336         iPhone11,8  11088  10:29:37  ปกติ (เหลืองใส)  0        90470
# 38337         iPhone11,8  11088  10:24:40  ปกติ (เหลืองใส)  1        91123
# 38341         iPhone11,8  11088  10:25:32  ปกติ (เหลืองใส)  1        99444
# 38342         iPhone10,5  05396  11:03:40  ปกติ (เหลืองใส)  0        99771
#
#        hcode                                               name  zone_code  \
# 4      13777            โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น        7.0
# 5      06307  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา        2.0
# 6      05328        โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์        7.0
# 7      06302                 โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง        2.0
# 8      05059              โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่        7.0
# ...      ...                                                ...        ...
# 38335  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38336  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38337  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38341  11088                                  โรงพยาบาลห้วยผึ้ง        7.0
# 38342  05396             โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านสูงเนิน        7.0
#
#                    zone_name  provincecode   province  amphurcode  \
# 4       สาขาพื้นที่(ขอนแก่น)          40.0    ขอนแก่น         1.0
# 5      สาขาพื้นที่(พิษณุโลก)          53.0  อุตรดิตถ์         7.0
# 6       สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        18.0
# 7      สาขาพื้นที่(พิษณุโลก)          53.0  อุตรดิตถ์         5.0
# 8       สาขาพื้นที่(ขอนแก่น)          44.0  มหาสารคาม        10.0
# ...                      ...           ...        ...         ...
# 38335   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38336   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38337   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38341   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        14.0
# 38342   สาขาพื้นที่(ขอนแก่น)          46.0  กาฬสินธุ์        10.0
#
#              amphur  tamboncode        tambon
# 4      เมืองขอนแก่น         1.0       ในเมือง
# 5             พิชัย         2.0      บ้านดารา
# 6           ฆ้องชัย         3.0      โคกสะอาด
# 7            ฟากท่า         4.0       สองห้อง
# 8             นาดูน         6.0         หัวดง
# ...             ...         ...           ...
# 38335      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38336      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38337      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38341      ห้วยผึ้ง         3.0  นิคมห้วยผึ้ง
# 38342        คำม่วง         9.0       เนินยาง
#
# [37820 rows x 19 columns]

# %% [markdown]
# # Save File

# %%
drop_data.to_csv('drop_data.csv', encoding='utf-8')
