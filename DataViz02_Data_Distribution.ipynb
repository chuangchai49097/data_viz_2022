# %% [markdown]
# <a href="https://colab.research.google.com/github/chuangchai49097/data_viz_2022/blob/main/DataViz02_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Scatter Plot

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter([1,-1],[2,-1]) # [x,y],[x,y]

# %%
plt.scatter(df['PetalLength'],df['SepalLength'])

# %% [markdown]
# ## เปลี่ยนสี

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='r')

# %% [markdown]
# ## ระบุสีให้แต่ละจุด

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# ### แทนค่าชื่อดอกไม้ด้วยตัวอักษรแทนสี

# %%
df2 = df.replace({'Iris-setosa':'r','Iris-versicolor':'g','Iris-virginica':'b'})

# %%
df2.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0          5.1         3.5          1.4         0.2    r
# 1          4.9         3.0          1.4         0.2    r
# 2          4.7         3.2          1.3         0.2    r
# 3          4.6         3.1          1.5         0.2    r
# 4          5.0         3.6          1.4         0.2    r

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])

# %% [markdown]
# ## เพิ่มรายละเอียดกราฟ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อ marker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers'); # ; ใส่ เพื่อให้ตัว code ที่ run ออกมาบังกราฟหายไป

# %% [markdown]
# ### ใช้ขนาดของ marker ในการแสดงค่าใน column

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s = df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s = df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica',s = df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ### ขยายขนาด marker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s = 40*df2['PetalWidth'][:50]) # ขยายขนาดโดยใช้เป็น 40 เท่าของ PetalWidth
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s = 40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='virginica',s = 40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ### ปรับความโปร่งใสของ marker เพื่อให้มองเห็นจุดที่ถูกบัง(Bubble Chart)

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha = 0.5,c=df2['Name'][:50],label='setosa',s = 40*df2['PetalWidth'][:50]) 
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha = 0.5,c=df2['Name'][50:100],label='versicolor',s = 40*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha = 0.5,c=df2['Name'][100:],label='virginica',s = 40*df2['PetalWidth'][100:])
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ### เปลี่ยนหน้าตาของ marker เพื่อความสวยงาม

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha = 0.5,c=df2['Name'][:50],label='setosa',s = 40*df2['PetalWidth'][:50],marker = 'X') 
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha = 0.5,c=df2['Name'][50:100],label='versicolor',s = 40*df2['PetalWidth'][50:100],marker = 'X')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha = 0.5,c=df2['Name'][100:],label='virginica',s = 40*df2['PetalWidth'][100:],marker = 'X')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha = 0.5,c=df2['Name'][:50],label='setosa',s = 40*df2['PetalWidth'][:50],marker = 'X') 
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha = 0.5,c=df2['Name'][50:100],label='versicolor',s = 40*df2['PetalWidth'][50:100],marker = '$c$')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha = 0.5,c=df2['Name'][100:],label='virginica',s = 40*df2['PetalWidth'][100:],marker = '$g$')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ## แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection ="3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],df2['SepalWidth'],c=df2['Name'],s = 80*df2['PetalWidth'])

# %%
ax = plt.axes(projection ="3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s = 80*df2['PetalWidth'][:50],label = 'setosa')
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],df2['SepalWidth'][50:100],c=df2['Name'][50:100],s = 80*df2['PetalWidth'][50:100],label = 'versicolor')
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s = 80*df2['PetalWidth'][100:],label = 'virginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# # Boxplot

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df['SepalLength'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffb83689190>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffb83613210>,
#   <matplotlib.lines.Line2D at 0x7ffb83613750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffb83618250>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffb83613cd0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffb83689750>,
#   <matplotlib.lines.Line2D at 0x7ffb83689c90>]}

# %%
plt.boxplot(df['SepalLength'],vert=False) # vert = False เป็นการทำให้ boxplot แสดงค่าในแนวนอน(vert มีค่า defalt เป็น True = แนวตั้ง)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffb8360a1d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffb836101d0>,
#   <matplotlib.lines.Line2D at 0x7ffb83610710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffb8359b210>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffb83610c90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffb8360a710>,
#   <matplotlib.lines.Line2D at 0x7ffb8360ac50>]}

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False)

# %%
ybp['medians'][0].get_ydata() # ดึงค่าออกมาจากแกน y
# Out:
# array([0.925, 1.075])

# %%
ybp['medians'][0].get_xdata() # ดึงค่าออกมาจากแกน x
# Out:
# array([5.8, 5.8])

# %%
ybp['whiskers'][0].get_xdata()
# Out:
# array([5.1, 4.3])

# %% [markdown]
# min

# %%
min(ybp['whiskers'][0].get_xdata())
# Out:
# 4.3

# %%
max(ybp['whiskers'][1].get_xdata())
# Out:
# 7.9

# %%
ybp['caps'][1].get_xdata()
# Out:
# array([7.9, 7.9])

# %% [markdown]
# q1

# %%
ybp['boxes'][0].get_xdata()
# Out:
# array([5.1, 5.1, 6.4, 6.4, 5.1])

# %%
ybp['boxes'][0].get_xdata()[0]
# Out:
# 5.1

# %%
max(ybp['whiskers'][0].get_xdata())
# Out:
# 5.1

# %% [markdown]
# q3

# %%
ybp['boxes'][0].get_xdata()[2]
# Out:
# 6.4

# %%
min(ybp['whiskers'][1].get_xdata())
# Out:
# 6.4

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans = True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffb8343fdd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffb83449e50>,
#   <matplotlib.lines.Line2D at 0x7ffb834503d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffb833d7450>],
#  'means': [<matplotlib.lines.Line2D at 0x7ffb83450ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffb83450950>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffb834493d0>,
#   <matplotlib.lines.Line2D at 0x7ffb83449910>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline = True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffb833b8d50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffb833c0d50>,
#   <matplotlib.lines.Line2D at 0x7ffb833c62d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffb833c6d90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffb833c6850>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffb833c02d0>,
#   <matplotlib.lines.Line2D at 0x7ffb833c0810>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline = True,showmeans = True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffb833f0090>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffb833fd210>,
#   <matplotlib.lines.Line2D at 0x7ffb833f9f50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffb8335ff10>],
#  'means': [<matplotlib.lines.Line2D at 0x7ffb83358590>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffb8352e710>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffb833d7a10>,
#   <matplotlib.lines.Line2D at 0x7ffb835c4fd0>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans = True,meanprops={'marker':'o'})
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffb83301350>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffb83307350>,
#   <matplotlib.lines.Line2D at 0x7ffb83307890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffb8330e910>],
#  'means': [<matplotlib.lines.Line2D at 0x7ffb8330e390>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffb83307e10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffb83301890>,
#   <matplotlib.lines.Line2D at 0x7ffb83301dd0>]}

# %% [markdown]
# # Quiz กลุ่ม final
#
# 1. เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min,max,q1,q2,q3
# 2. วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %% [markdown]
# 1. เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min,max,q1,q2,q3

# %%
def box_vals(ybp,vert=True) :
    if vert == True :   
        q1 = ybp['boxes'][0].get_ydata()[0]
        q2 = ybp['medians'][0].get_ydata()[0]
        q3 = ybp['boxes'][0].get_ydata()[2]
        mmin = min(ybp['caps'][0].get_ydata())
        mmax = max(ybp['caps'][1].get_ydata())
    else :
        q1 = ybp['boxes'][0].get_xdata()[0]
        q2 = ybp['medians'][0].get_xdata()[0]
        q3 = ybp['boxes'][0].get_xdata()[2]
        mmin = min(ybp['caps'][0].get_xdata())
        mmax = max(ybp['caps'][1].get_xdata())
    return  q1,q2,q3,mmin,mmax

# %%
box_vals(ybp,vert=False)
# Out:
# (5.1, 5.8, 6.4, 4.3, 7.9)

# %% [markdown]
# 2. วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}
